# %%
import pandas as pd 
from sklearn.model_selection import train_test_split 
import time
import numpy as np 
from sklearn.preprocessing import StandardScaler 
from sklearn.feature_selection import SelectKBest, chi2
from sklearn. feature_selection import RFE 
from sklearn.linear_model import LogisticRegression 
import pickle
import matplotlib.pyplot as plt

# %%
def selectkbest(indep_X,dep_Y,n):
    test =  SelectKBest(score_func=chi2, k=n)
    fit1=test.fit(indep_X,dep_Y)
    selectk_features = fit1. transform(indep_X)
    return selectk_features
def split_scalar(indep_X, dep_Y) :
    X_train, X_test, y_train, y_test =train_test_split(indep_X, dep_Y, test_size = 0.25, random_state = 0)
    sc =StandardScaler()
    X_train =sc.fit_transform (X_train)
    X_test =sc.transform(X_test)
    return X_train, X_test, y_train, y_test
def cm_prediction(classifier, test):
    y_pred=classifier.predict(X_test)
    # Making the Confusion Matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_pred)
    from sklearn.metrics import accuracy_score 
    from sklearn.metrics import classification_report
    #from sklearn.metrics import confusion matrix
    #cm = confusion matrix(y_test, y_pred)
    Accuracy=accuracy_score(y_test, y_pred)
    report=classification_report(y_test, y_pred)
    return classifier,Accuracy, report, X_test, y_test, cm
def logistic(X_train,y_train, X_test):
    # Fitting K-NN to the Training set
    from sklearn.linear_model import LogisticRegression 
    classifier=LogisticRegression(random_state=0)
    classifier.fit(X_train, y_train)
    classifier, Accuracy, report,X_test, y_test, cm=cm_prediction(classifier,X_test) 
    return classifier, Accuracy, report,X_test,y_test,cm
def svm_linear(X_train,y_train,X_test):
    from sklearn. svm import SVC
    classifier = SVC(kernel = 'linear', random_state = 0)
    classifier.fit(X_train, y_train)
    classifier, Accuracy, report,X_test, y_test, cm=cm_prediction(classifier,X_test)
    return classifier,Accuracy, report,X_test, y_test, cm
def svm_NL(X_train,y_train,X_test):
    from sklearn. svm import SVC
    classifier = SVC(kernel = 'rbf', random_state = 0)
    classifier.fit(X_train, y_train)
    classifier, Accuracy, report,X_test, y_test, cm=cm_prediction(classifier,X_test)
    return classifier, Accuracy, report,X_test,y_test, cm
def Navie(X_train,y_train,X_test):
    # Fitting K-NN to the Training set
    from sklearn.naive_bayes import GaussianNB
    classifier = GaussianNB ()
    classifier. fit(X_train, y_train)
    classifier, Accuracy, report,X_test, y_test, cm=cm_prediction(classifier,X_test)
    return classifier, Accuracy, report,X_test, y_test, cm
def knn(X_train,y_train,X_test):
    # Fitting K-NN to the Training set
    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier (n_neighbors=5,p=2, metric='minkowski')
    classifier. fit(X_train, y_train)
    classifier, Accuracy, report,X_test, y_test, cm=cm_prediction(classifier,X_test)
    return classifier, Accuracy, report,X_test, y_test, cm
def Decision(X_train,y_train,X_test):
    # Fitting K-NN to the Training set
    from sklearn.tree import DecisionTreeClassifier
    classifier = DecisionTreeClassifier (random_state=0,criterion='gini')
    classifier. fit(X_train, y_train)
    classifier, Accuracy, report,X_test, y_test, cm=cm_prediction(classifier,X_test)
    return classifier, Accuracy, report,X_test, y_test, cm
def Random(X_train,y_train,X_test):
    # Fitting K-NN to the Training set
    from sklearn.ensemble import RandomForestClassifier
    classifier =  RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
    classifier. fit(X_train, y_train)
    classifier, Accuracy, report,X_test, y_test, cm=cm_prediction(classifier,X_test)
    return classifier, Accuracy, report,X_test, y_test, cm

# %%
def selectk_Classiflcation(acclog, accsvml, accsvmnl, accknn, accnav, accdes, accrf):
    dataframe=pd.DataFrame (index=['ChiSquare' ], columns=['Logistic', 'SVMl', 'SVMnl', 'KNN', 'Navie', 'Decision', 'Random'])
    for number,idex in enumerate (dataframe.index) :
         dataframe.loc[idx,'Logistic']=acclog[number]
         dataframe.loc[idx,'SVMl']=accsvml [number]
         dataframe.loc [idx,'SVMnl']=accsvmnl [number]
         dataframe.loc [idx,'KNN' ]=accknn[number]
         dataframe.loc[idx,'Navie']=accnav[number]
         dataframe.loc[idx,'Decision']=accdes [number] 
         dataframe.loc[idx,'Random']=accrf [number ]
    return dataframe

# %%
dataset1=pd. read_csv("prep.csv", index_col=None)
df2=dataset1
df2=pd.get_dummies(df2,drop_first=True)
df2=df2.drop('id', axis=1)
df2=df2.drop('classification_ckd\t', axis=1)
indep_X=df2.drop('classification_notckd', axis=1)
dep_Y=df2['classification_notckd']

# %%
df2.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo',
#        'pcv', 'wc', 'rc', 'rbc_normal', 'pc_normal', 'pcc_present',
#        'ba_present', 'htn_yes', 'dm_\tyes', 'dm_ yes', 'dm_no', 'dm_yes',
#        'cad_no', 'cad_yes', 'appet_poor', 'pe_yes', 'ane_yes',
#        'classification_notckd'],
#       dtype='object')

# %%
kbest=selectkbest(indep_X,dep_Y,6)
acclog=[]
accsvml=[] 
accsvmnl=[]
accknn=[]
accnav=[]
accdes=[]
accrf=[]

# %%
kbest
# Out:
# array([[1.00e+00, 1.21e+02, 3.60e+01, 1.20e+00, 4.40e+01, 7.80e+03],
#        [4.00e+00, 1.21e+02, 1.80e+01, 8.00e-01, 3.80e+01, 6.00e+03],
#        [2.00e+00, 4.23e+02, 5.30e+01, 1.80e+00, 3.10e+01, 7.50e+03],
#        ...,
#        [0.00e+00, 1.00e+02, 2.60e+01, 6.00e-01, 4.90e+01, 6.60e+03],
#        [0.00e+00, 1.14e+02, 5.00e+01, 1.00e+00, 5.10e+01, 7.20e+03],
#        [0.00e+00, 1.31e+02, 1.80e+01, 1.10e+00, 5.30e+01, 6.80e+03]])

# %%
X_train,X_test,y_train,y_test=split_scalar(kbest,dep_Y)
classifler,Accuracy, report,X_test, y_test, cm=logistic(X_train, y_train,X_test)
acclog.append (Accuracy)
classifler,Accuracy, report,X_test,y_test, cm=svm_linear(X_train,y_train,X_test)
accsvml.append (Accuracy)
classifier,Accuracy, report,X_test,y_test, cm=svm_NL(X_train,y_train,X_test)
accsvmnl. append (Accuracy)
classifier,Accuracy, report,X_test,y_test, cm=knn(X_train,y_train,X_test)
accknn.append (Accuracy)
classifier,Accuracy, report,X_test, y_test, cm=Navie(X_train,y_train,X_test)
accnav.append (Accuracy)
classifier,Accuracy, report,X_test, y_test, cm=Decision(X_train,y_train,X_test)
accdes. append(Accuracy)
classifler, Accuracy, report,X_test,y_test, cm=Random(X_train,y_train, X_test)
accrf. append (Accuracy)
result=selectk_Classiflcation(acclog,accsvml,accsvmnl, accknn, accnav, accdes, accrf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 16
#      14 classifler, Accuracy, report,X_test,y_test, cm=Random(X_train,y_train, X_test)
#      15 accrf. append (Accuracy)
# ---> 16 result=selectk_Classiflcation(acclog,accsvml,accsvmnl, accknn, accnav, accdes, accrf)
#
# Cell In[96], line 4, in selectk_Classiflcation(acclog, accsvml, accsvmnl, accknn, accnav, accdes, accrf)
#       2 dataframe=pd.DataFrame (index=['ChiSquare' ], columns=['Logistic', 'SVMl', 'SVMnl', 'KNN', 'Navie', 'Decision', 'Random'])
#       3 for number,idex in enumerate (dataframe.index) :
# ----> 4      dataframe.loc[idx,'Logistic']=acclog[number]
#       5      dataframe.loc[idx,'SVMl']=accsvml [number]
#       6      dataframe.loc [idx,'SVMnl']=accsvmnl [number]
#
# NameError: name 'idx' is not defined

# %%
result#5
# Out:
#           Logistic  SVMl SVMnl   KNN Navie Decision Random
# ChiSquare      0.9  0.92  0.91  0.93   0.9     0.96   0.94

# %%
result#4
# Out:
#           Logistic  SVMl SVMnl   KNN Navie Decision Random
# ChiSquare     0.88  0.89  0.88  0.91  0.88     0.96   0.97

# %%
result#3
# Out:
#           Logistic  SVMl SVMnl   KNN Navie Decision Random
# ChiSquare     0.85  0.84  0.86  0.88  0.82     0.86   0.88

# %%
result#6
# Out:
#           Logistic  SVMl SVMnl   KNN Navie Decision Random
# ChiSquare     0.95  0.94  0.96  0.96  0.94     0.97   0.98
